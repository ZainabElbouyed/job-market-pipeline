# %% [markdown]
# # 📊 Analyse Statistique
# ## Exploration des données

# %%
import sys
sys.path.append('..')

import pandas as pd
from analysis.stats import JobMarketAnalyzer
from analysis.reports import generate_report
    
print("✅ Modules importés")
# Out:
# ✅ Modules importés

# %%
# Charger les données nettoyées

df = pd.read_csv('../data/processed/jobs_clean.csv')
print(f"📊 {len(df)} offres chargées")
# Out:
# 📊 75 offres chargées

# %%
# Initialiser l'analyseur

analyzer = JobMarketAnalyzer(df)

# %%
# Stats générales

analyzer.basic_stats()
# Out:
# 📊 STATISTIQUES GÉNÉRALES
# ========================================
# total_offres   : 75
# entreprises    : 37
# villes         : 24
# regions        : 16
# date_min       : 2026-03-09
# date_max       : 2026-03-10
# {'total_offres': 75,
#  'entreprises': 37,
#  'villes': 24,
#  'regions': 16,
#  'date_min': '2026-03-09',
#  'date_max': '2026-03-10'}

# %%
# Top compétences

analyzer.top_skills(15)
# Out:
# 🏆 TOP 15 COMPÉTENCES
# ========================================
#  1. Vente                           20 (26.7%)
#  2. Gestion                         18 (24.0%)
#  3. Production                      16 (21.3%)
#  4. Maintenance                     16 (21.3%)
#  5. Qualité                         15 (20.0%)
#  6. Comptabilité                    13 (17.3%)
#  7. Finance                         12 (16.0%)
#  8. Assistanat                      10 (13.3%)
#  9. Secrétariat                      9 (12.0%)
# 10. Électromécanique                 9 (12.0%)
# 11. Marketing                        7 (9.3%)
# 12. Communication                    7 (9.3%)
# 13. Management                       7 (9.3%)
# 14. Non spécifié                     7 (9.3%)
# 15. Prospection                      6 (8.0%)
# [('Vente', 20),
#  ('Gestion', 18),
#  ('Production', 16),
#  ('Maintenance', 16),
#  ('Qualité', 15),
#  ('Comptabilité', 13),
#  ('Finance', 12),
#  ('Assistanat', 10),
#  ('Secrétariat', 9),
#  ('Électromécanique', 9),
#  ('Marketing', 7),
#  ('Communication', 7),
#  ('Management', 7),
#  ('Non spécifié', 7),
#  ('Prospection', 6)]

# %%
# Top régions

analyzer.top_regions()
# Out:
# 📍 TOP 10 RÉGIONS
# ========================================
# Casablanca-Mohammedia                45 (60.0%)
# Rabat-Salé-Kénitra                    9 (12.0%)
# Tanger-Tétouan-Al Hoceïma             4 (5.3%)
# Agadir                                4 (5.3%)
# Oujda                                 2 (2.7%)
# Casablanca-Mohammedia - Fès - Rabat-Salé-Kénitra   1 (1.3%)
# Casablanca-Mohammedia - Tanger-Tétouan-Al Hoceïma   1 (1.3%)
# Agadir - Béni Mellal-Khénifra - Casablanca-Mohammedia - Fès - Laâyoune - Marrakech-Safi - Meknès - Rabat-Salé-Kénitra   1 (1.3%)
# Fès                                   1 (1.3%)
# Laâyoune                              1 (1.3%)
# region
# Casablanca-Mohammedia                                                                                                    45
# Rabat-Salé-Kénitra                                                                                                        9
# Tanger-Tétouan-Al Hoceïma                                                                                                 4
# Agadir                                                                                                                    4
# Oujda                                                                                                                     2
# Casablanca-Mohammedia - Fès - Rabat-Salé-Kénitra                                                                          1
# Casablanca-Mohammedia - Tanger-Tétouan-Al Hoceïma                                                                         1
# Agadir - Béni Mellal-Khénifra - Casablanca-Mohammedia - Fès - Laâyoune - Marrakech-Safi - Meknès - Rabat-Salé-Kénitra     1
# Fès                                                                                                                       1
# Laâyoune                                                                                                                  1
# Name: count, dtype: int64

# %%
# Distribution contrats

analyzer.contract_distribution()
# Out:
# 📋 TYPES DE CONTRATS
# ========================================
# CDI              56 (74.7%)
# Intérim           8 (10.7%)
# CDI - CDD - Intérim   3 (4.0%)
# CDI - Intérim     2 (2.7%)
# CDD               2 (2.7%)
# Freelance         1 (1.3%)
# Anapec            1 (1.3%)
# CDI - CDD - Anapec   1 (1.3%)
# CDD - Intérim     1 (1.3%)
# contrat
# CDI                    56
# Intérim                 8
# CDI - CDD - Intérim     3
# CDI - Intérim           2
# CDD                     2
# Freelance               1
# Anapec                  1
# CDI - CDD - Anapec      1
# CDD - Intérim           1
# Name: count, dtype: int64

# %%
# Générer un rapport

generate_report(df, 'rapport_marche_emploi.md')
# Out:
# ✅ Rapport généré: rapport_marche_emploi.md
