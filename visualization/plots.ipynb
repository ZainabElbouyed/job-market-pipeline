# %% [markdown]
# # 🎨 VISUALIZATION - Création des graphiques
# ## Objectif: Générer les visualisations

# %%
import sys
sys.path.append('..')
import pandas as pd
from visualization.plots import JobMarketVisualizer

# %%
# Chargement

df = pd.read_csv('../data/processed/jobs_clean.csv')
viz = JobMarketVisualizer(df)
# Out:
# ✅ Styles configurés

# %%
# Top compétences

viz.plot_top_skills(save=True)

# %%
# Top villes

viz.plot_top_villes(save=True)

# %%
# Types de contrats

viz.plot_contracts(save=True)

# %%
# Nuage de mots

viz.plot_wordcloud(save=True)

# %%
# Heatmap compétences/régions

viz.plot_skills_heatmap(save=True)
# Out:
# 🔥 Création du heatmap compétences/régions...
# ✅ Heatmap sauvegardé: outputs/skills_heatmap.png

# %%
# Dashboard complet

viz.create_all_plots()
# Out:
# 🎨 Création des visualisations...
# ✅ Visualisations sauvegardées dans outputs/
