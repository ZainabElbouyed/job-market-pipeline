# %% [markdown]
# # 🔄 Pipeline ETL
# ## Nettoyage et transformation

# %%
import sys
sys.path.append('..')
  
import pandas as pd
import glob
import os
from pipeline.cleaner import DataCleaner
from pipeline.transformer import DataTransformer
    
print("✅ Modules importés")
# Out:
# ✅ Modules importés

# %%
# Charger le dernier fichier brut

csv_files = glob.glob('../data/raw/jobs_*.csv')
if csv_files:
    latest_file = max(csv_files, key=os.path.getctime)
    df_raw = pd.read_csv(latest_file)
    print(f"📁 Fichier chargé: {latest_file}")
    print(f"📊 Dimensions: {df_raw.shape}")
else:
    print("❌ Aucun fichier trouvé")
# Out:
# 📁 Fichier chargé: ../data/raw\jobs_20260310_191210.csv
# 📊 Dimensions: (728, 10)

# %%
# Nettoyage

cleaner = DataCleaner()
df_clean = cleaner.clean(df_raw)
df_clean.head()
# Out:
#                                                  url  \
# 0  https://www.emploi.ma/offre-emploi-maroc/pilot...
# 1  https://www.emploi.ma/offre-emploi-maroc/respo...
# 2  https://www.emploi.ma/offre-emploi-maroc/chef-...
# 3  https://www.emploi.ma/offre-emploi-maroc/assis...
# 4  https://www.emploi.ma/offre-emploi-maroc/assis...
#
#                                                titre  \
# 0                            Pilote Qualité - Tanger
# 1               Responsable Maintenance - Casablanca
# 2  Chef d’Équipe – Installation Photovoltaïque - ...
# 3  Assistant(e) Marketing et Communication - Bous...
# 4               Assistante de Direction - Casablanca
#
#                             entreprise date_publication  \
# 0                        TESCA MOROCCO       2026-03-04
# 1                                BOTTU       2026-02-12
# 2  TECTRA CASA TERTIAIRE – RECRUTEMENT       2026-03-10
# 3                            SEPALUMIC       2026-02-24
# 4                           GROUPE MCE       2026-02-24
#
#                       region       ville        contrat  \
# 0  Tanger-Tétouan-Al Hoceïma      Tanger            CDI
# 1      Casablanca-Mohammedia  Casablanca            CDI
# 2      Casablanca-Mohammedia  Casablanca  CDI - Intérim
# 3      Casablanca-Mohammedia   Bouskoura            CDI
# 4      Casablanca-Mohammedia  Casablanca            CDI
#
#                                           experience  \
# 0                    Expérience entre 2 ans et 5 ans
# 1                   Expérience entre 5 ans et 10 ans
# 2  Expérience entre 2 ans et 5 ans - Expérience e...
# 3                    Expérience entre 2 ans et 5 ans
# 4  Expérience entre 2 ans et 5 ans - Expérience e...
#
#                             niveau_etude  \
# 0                          Bac+5 et plus
# 1                          Bac+5 et plus
# 2                          Bac+2 - Bac+3
# 3                                  Bac+3
# 4  Bac+2 - Bac+3 - Bac+4 - Bac+5 et plus
#
#                                     competences_cles
# 0  Qualité - Maintenance - Production - Managemen...
# 1  Maintenance - Production - Électromécanique - ...
# 2  Production - Qualité - Maintenance - Montage -...
# 3  Communication Marketing - Marketing Digital - ...
# 4  Assistanat - Support - POWERPOINT - Administra...

# %%
# Transformation

transformer = DataTransformer()
df_trans = transformer.transform(df_clean)
df_trans.head()
# Out:
#                                                  url  \
# 0  https://www.emploi.ma/offre-emploi-maroc/pilot...
# 1  https://www.emploi.ma/offre-emploi-maroc/respo...
# 2  https://www.emploi.ma/offre-emploi-maroc/chef-...
# 3  https://www.emploi.ma/offre-emploi-maroc/assis...
# 4  https://www.emploi.ma/offre-emploi-maroc/assis...
#
#                                                titre  \
# 0                            Pilote Qualité - Tanger
# 1               Responsable Maintenance - Casablanca
# 2  Chef d’Équipe – Installation Photovoltaïque - ...
# 3  Assistant(e) Marketing et Communication - Bous...
# 4               Assistante de Direction - Casablanca
#
#                             entreprise date_publication  \
# 0                        TESCA MOROCCO       2026-03-04
# 1                                BOTTU       2026-02-12
# 2  TECTRA CASA TERTIAIRE – RECRUTEMENT       2026-03-10
# 3                            SEPALUMIC       2026-02-24
# 4                           GROUPE MCE       2026-02-24
#
#                       region       ville        contrat  \
# 0  Tanger-Tétouan-Al Hoceïma      Tanger            CDI
# 1      Casablanca-Mohammedia  Casablanca            CDI
# 2      Casablanca-Mohammedia  Casablanca  CDI - Intérim
# 3      Casablanca-Mohammedia   Bouskoura            CDI
# 4      Casablanca-Mohammedia  Casablanca            CDI
#
#                                           experience  \
# 0                    Expérience entre 2 ans et 5 ans
# 1                   Expérience entre 5 ans et 10 ans
# 2  Expérience entre 2 ans et 5 ans - Expérience e...
# 3                    Expérience entre 2 ans et 5 ans
# 4  Expérience entre 2 ans et 5 ans - Expérience e...
#
#                             niveau_etude  \
# 0                          Bac+5 et plus
# 1                          Bac+5 et plus
# 2                          Bac+2 - Bac+3
# 3                                  Bac+3
# 4  Bac+2 - Bac+3 - Bac+4 - Bac+5 et plus
#
#                                     competences_cles  \
# 0  Qualité - Maintenance - Production - Managemen...
# 1  Maintenance - Production - Électromécanique - ...
# 2  Production - Qualité - Maintenance - Montage -...
# 3  Communication Marketing - Marketing Digital - ...
# 4  Assistanat - Support - POWERPOINT - Administra...
#
#                                          skills_list       experience_cat  \
# 0  [Qualité, Maintenance, Production, Management ...     Junior (2-5 ans)
# 1  [Maintenance, Production, Électromécanique, Ma...  Confirmé (5-10 ans)
# 2  [Production, Qualité, Maintenance, Montage, Câ...     Junior (2-5 ans)
# 3  [Communication Marketing, Marketing Digital, S...     Junior (2-5 ans)
# 4  [Assistanat, Support, POWERPOINT, Administrati...     Junior (2-5 ans)
#
#    annee  mois
# 0   2026     3
# 1   2026     2
# 2   2026     3
# 3   2026     2
# 4   2026     2

# %%
# Sauvegarde

df_trans.to_csv('../data/processed/jobs_clean.csv', index=False)
print(f"✅ Données sauvegardées dans data/processed/jobs_clean.csv")
# Out:
# ✅ Données sauvegardées dans data/processed/jobs_clean.csv
